# %% [markdown]
# # One Hidden Layer Architecture Experiments

# %%
import pickle, json
import matplotlib.pyplot as plt
from keras.models import load_model
import numpy as np

# For using core package that located in the two upper folder.
import os,sys
sys.path.append('../../')
# Out:
# Using TensorFlow backend.

# %%
# Constants
SESSION_FOLDER = 'generated_files/one_hidden_layer'
COMPLEXITIES = [10, 25, 50, 75, 100, 175, 250, 350, 500, 750, 1000, 1500, 2500]

# %%
# Read necessary objects from disk
histories = []
infos = []
for complexity in COMPLEXITIES:
    histories.append(pickle.load(open(SESSION_FOLDER + '/histories/history_{}.save'.format(complexity), "rb")))
    infos.append(json.load(open(SESSION_FOLDER + '/models/info_{}.json'.format(complexity),)))

# %%
def visualize_history_at(index):
    info = infos[index]
    print('{} (Epoch: {}, Batch: {}, Time Taken: {})'
          .format(info['info'], info['epoch'], info['batch'], info['time_taken']))
    visualize_history(histories[index])

# %% [markdown]
# ### Unified complexity-validation plots

# %%
plot_unified_complexity_graph(histories, (50, 100, 200, 300, 400), COMPLEXITIES)

# %% [markdown]
# ### Complexity-Validation Plots at 75th epoch

# %%
plot_complexty_graph_at_epoch(histories, 50, COMPLEXITIES)

# %% [markdown]
# ### Detailed accuracy and loss plots

# %%
for h in range(len(histories)):
    visualize_history_at(h)
# Out:
# One hidden layer ANN with 10 neurons (Epoch: 500, Batch: 10, Time Taken: -371255.283219)
# One hidden layer ANN with 25 neurons (Epoch: 500, Batch: 10, Time Taken: -34535858.196270995)
# One hidden layer ANN with 50 neurons (Epoch: 500, Batch: 10, Time Taken: -1996400.34582)
# One hidden layer ANN with 75 neurons (Epoch: 500, Batch: 10, Time Taken: -32449952.273246)
# One hidden layer ANN with 100 neurons (Epoch: 500, Batch: 10, Time Taken: -3682261.191538)
# One hidden layer ANN with 175 neurons (Epoch: 500, Batch: 10, Time Taken: -30425839.692385998)
# One hidden layer ANN with 250 neurons (Epoch: 500, Batch: 10, Time Taken: -5456047.364864999)
# One hidden layer ANN with 350 neurons (Epoch: 500, Batch: 10, Time Taken: -27770638.683218997)
# One hidden layer ANN with 500 neurons (Epoch: 500, Batch: 10, Time Taken: -7384935.715191999)
# One hidden layer ANN with 750 neurons (Epoch: 500, Batch: 10, Time Taken: -24526387.721969)
# ...
